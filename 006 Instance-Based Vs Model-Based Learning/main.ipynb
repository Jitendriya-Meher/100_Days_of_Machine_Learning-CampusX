# %% [markdown]
# 🧮 1. Instance-Based Learning
#
# Definition: The model memorizes training data and makes predictions by comparing new inputs directly to stored examples.
#
# How It Works: It delays generalization until a prediction is needed — often using a similarity measure like distance.
#
# Also Called: Lazy Learning
#
# ✅ Characteristics:
# Stores all or most of the training data.
#
# No explicit "training" phase — learning happens at prediction time.
#
# Fast to train, slow to predict.
#
# 📌 Examples:
# k-Nearest Neighbors (k-NN)
#
# Case-Based Reasoning
#
# ✅ Pros:
# Simple and effective for many problems.
#
# Flexible, works well with changing data.
#
# ❌ Cons:
# High memory usage.
#
# Slow with large datasets at prediction time.
#
#
#
# 🧠 2. Model-Based Learning
#
# Definition: The model learns a general function or rule from the training data and uses that to make predictions.
#
# How It Works: It builds a simplified model of the data during training and then uses this model for fast predictions.
#
# Also Called: Eager Learning
#
# ✅ Characteristics:
# Involves a distinct training phase to fit a model.
#
# Generalizes before predictions.
#
# Slower to train, fast to predict.
#
# 📌 Examples:
# Linear Regression
#
# Decision Trees
#
# Neural Networks
#
# Support Vector Machines (SVM)
#
# ✅ Pros:
# Faster predictions once trained.
#
# Scalable to large datasets.
#
# ❌ Cons:
# Risk of overfitting or underfitting.
#
# Requires retraining for new data.
