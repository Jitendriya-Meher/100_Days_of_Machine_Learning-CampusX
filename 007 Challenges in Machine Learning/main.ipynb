# %% [markdown]
# ⚠️ 1. Quality and Quantity of Data
#
# Challenge: ML models need large, high-quality, and relevant data to perform well.
#
# Issues:
#
# Missing, noisy, or inconsistent data
#
# Imbalanced classes (e.g., 95% negative, 5% positive)
#
# Limited labeled data for supervised learning
#
# 🔍 2. Overfitting & Underfitting
#
# Overfitting: The model memorizes training data, performing poorly on new data.
#
# Underfitting: The model is too simple and fails to capture underlying patterns.
#
# ⚖️ 3. Bias and Fairness
#
# Challenge: Biased data leads to biased models, which can reinforce unfair outcomes.
#
# Examples:
#
# Gender or racial bias in hiring or loan approval models
#
# 🔄 4. Model Interpretability
#
# Challenge: Complex models (like deep learning) can act like "black boxes."
#
# Problem: Hard to explain how decisions are made — a major concern in fields like healthcare or finance.
#
# 📉 5. Generalization to New Data
#
# Challenge: Models may perform well on training data but fail in real-world scenarios.
#
# Reason: Distribution shift — when the test data differs from the training data.
#
# 🧪 6. Evaluation and Validation
#
# Challenge: Choosing the right evaluation metrics and validation strategies (e.g., cross-validation).
#
# Problem: Misleading accuracy if test data isn't representative.
#
# 🛠️ 7. Algorithm & Model Selection
#
# Challenge: No one-size-fits-all algorithm — different problems require different techniques.
#
# Problem: Requires experimentation and expertise.
#
# 💻 8. Computational Resources
#
# Challenge: Training large models (e.g., deep neural networks) requires powerful hardware (GPUs/TPUs).
#
# Problem: Cost and accessibility limitations.
#
# 🔐 9. Security and Privacy
#
# Challenge: Handling sensitive data while complying with laws (e.g., GDPR).
#
# Risks: Data breaches, model inversion attacks.
#
# 🌎 10. Deployment and Maintenance
#
# Challenge: Moving from a trained model to a production-ready system.
#
# Includes:
#
# Monitoring model drift
#
# Updating models over time
#
# Integration with existing systems
